# %%
#Run File Section

# %%
println("Hello World")

using Pkg
Pkg.gc()
# Out:
# Hello World
#       Active manifest files: 1 found
#       Active artifact files: 0 found
#       Active scratchspaces: 0 found
#      Deleted no artifacts, repos, packages or scratchspaces

# %%
import Pkg
using Pkg

Pkg.add("Images")
Pkg.add("ColorTypes")
# Out:
#     Updating registry at `C:\Users\2572664c\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed TiledIteration ─────────────────── v0.5.0
#    Installed JpegTurbo_jll ──────────────────── v3.1.1+0
#    Installed ImageIO ────────────────────────── v0.6.9
#    Installed OffsetArrays ───────────────────── v1.17.0
#    Installed JpegTurbo ──────────────────────── v0.1.6
#    Installed ImageSegmentation ──────────────── v1.9.0
#    Installed AxisArrays ─────────────────────── v0.4.7
#    Installed TiffImages ─────────────────────── v0.11.4
#    Installed LERC_jll ───────────────────────── v3.0.0+1
#    Installed PNGFiles ───────────────────────── v0.4.4
#    Installed ImageMagick ────────────────────── v1.4.2
#    Installed FFTW ───────────────────────────── v1.9.0
#    Installed HistogramThresholding ──────────── v0.3.1
#    Installed Sixel ──────────────────────────── v0.1.5
#    Installed RegionTrees ────────────────────── v0.3.2
#    Installed ProgressMeter ──────────────────── v1.10.4
#    Installed NearestNeighbors ───────────────── v0.4.22
#    Installed StaticArrays ───────────────────── v1.9.14
#    Installed ScopedValues ───────────────────── v1.4.0
#    Installed Images ─────────────────────────── v0.26.2
#    Installed OpenEXR ────────────────────────── v0.3.3
#    Installed CEnum ──────────────────────────── v0.5.0
#    Installed IntelOpenMP_jll ────────────────── v2025.2.0+0
#    Installed FileIO ─────────────────────────── v1.17.0
#    Installed Statistics ─────────────────────── v1.11.1
#    Installed ColorSchemes ───────────────────── v3.30.0
#    Installed Polynomials ────────────────────── v4.1.0
#    Installed MetaGraphs ─────────────────────── v0.8.0
#    Installed Netpbm ─────────────────────────── v1.1.1
#    Installed Static ─────────────────────────── v1.2.0
#    Installed SLEEFPirates ───────────────────── v0.6.43
#    Installed Xorg_libXau_jll ────────────────── v1.0.13+0
#    Installed Distances ──────────────────────── v0.10.12
#    Installed Missings ───────────────────────── v1.2.0
#    Installed JLD2 ───────────────────────────── v0.5.15
#    Installed RealDot ────────────────────────── v0.1.0
#    Installed IrrationalConstants ────────────── v0.2.4
#    Installed SIMD ───────────────────────────── v3.7.1
#    Installed ImageContrastAdjustment ────────── v0.3.12
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed ArnoldiMethod ──────────────────── v0.4.0
#    Installed Giflib_jll ─────────────────────── v5.2.3+0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed Clustering ─────────────────────── v0.15.8
#    Installed PtrArrays ──────────────────────── v1.3.0
#    Installed QOI ────────────────────────────── v1.0.1
#    Installed XZ_jll ─────────────────────────── v5.8.1+0
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed NaNMath ────────────────────────── v1.1.3
#    Installed PkgVersion ─────────────────────── v0.3.3
#    Installed StaticArraysCore ───────────────── v1.4.3
#    Installed Graphics ───────────────────────── v1.1.3
#    Installed ThreadingUtilities ─────────────── v0.5.5
#    Installed WebP ───────────────────────────── v0.1.3
#    Installed TranscodingStreams ─────────────── v0.11.3
#    Installed CustomUnitRanges ───────────────── v1.0.2
#    Installed ImageMetadata ──────────────────── v0.9.10
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed Ratios ─────────────────────────── v0.4.5
#    Installed DataStructures ─────────────────── v0.18.22
#    Installed CatIndices ─────────────────────── v0.2.2
#    Installed Graphs ─────────────────────────── v1.13.0
#    Installed MappedArrays ───────────────────── v0.4.2
#    Installed ComputationalResources ─────────── v0.3.2
#    Installed Colors ─────────────────────────── v0.13.1
#    Installed ImageMagick_jll ────────────────── v7.1.1048+0
#    Installed PaddedViews ────────────────────── v0.5.12
#    Installed Compat ─────────────────────────── v4.18.0
#    Installed StatsAPI ───────────────────────── v1.7.1
#    Installed ImageTransformations ───────────── v0.10.2
#    Installed CommonWorldInvalidations ───────── v1.0.0
#    Installed StaticArrayInterface ───────────── v1.8.0
#    Installed LazyModules ────────────────────── v0.3.1
#    Installed Xorg_libxcb_jll ────────────────── v1.17.1+0
#    Installed MosaicViews ────────────────────── v0.3.4
#    Installed libpng_jll ─────────────────────── v1.6.50+0
#    Installed StatsBase ──────────────────────── v0.34.5
#    Installed ColorTypes ─────────────────────── v0.12.1
#    Installed ImageCore ──────────────────────── v0.10.5
#    Installed ImageCorners ───────────────────── v0.1.3
#    Installed ImageFiltering ─────────────────── v0.7.10
#    Installed oneTBB_jll ─────────────────────── v2022.0.0+0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.6
#    Installed LayoutPointers ─────────────────── v0.1.17
#    Installed Xorg_libXext_jll ───────────────── v1.3.7+0
#    Installed TensorCore ─────────────────────── v0.1.1
#    Installed Zstd_jll ───────────────────────── v1.5.7+1
#    Installed Inflate ────────────────────────── v0.1.5
#    Installed ImageQualityIndexes ────────────── v0.3.7
#    Installed HashArrayMappedTries ───────────── v0.2.0
#    Installed ImageShow ──────────────────────── v0.3.8
#    Installed IntegralArrays ─────────────────── v0.1.6
#    Installed Imath_jll ──────────────────────── v3.1.11+0
#    Installed MKL_jll ────────────────────────── v2025.2.0+0
#    Installed Setfield ───────────────────────── v1.1.2
#    Installed LoopVectorization ──────────────── v0.12.172
#    Installed Libtiff_jll ────────────────────── v4.5.1+1
#    Installed AbstractFFTs ───────────────────── v1.5.0
#    Installed JLLWrappers ────────────────────── v1.7.1
#    Installed ConstructionBase ───────────────── v1.6.0
#    Installed ColorVectorSpace ───────────────── v0.11.0
#    Installed OrderedCollections ─────────────── v1.8.1
#    Installed CoordinateTransformations ──────── v0.6.4
#    Installed ChainRulesCore ─────────────────── v1.25.2
#    Installed PolyesterWeave ─────────────────── v0.2.2
#    Installed ArrayInterface ─────────────────── v7.19.0
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed Interpolations ─────────────────── v0.16.1
#    Installed Ghostscript_jll ────────────────── v9.55.0+4
#    Installed StackViews ─────────────────────── v0.1.2
#    Installed AliasTables ────────────────────── v1.1.3
#    Installed LogExpFunctions ────────────────── v0.3.29
#    Installed LittleCMS_jll ──────────────────── v2.16.0+0
#    Installed Quaternions ────────────────────── v0.7.6
#    Installed CloseOpenIntervals ─────────────── v0.1.13
#    Installed MacroTools ─────────────────────── v0.5.16
#    Installed Rotations ──────────────────────── v1.7.1
#    Installed RangeArrays ────────────────────── v0.3.2
#    Installed FFTW_jll ───────────────────────── v3.3.11+0
#    Installed SimpleTraits ───────────────────── v0.9.4
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed OpenEXR_jll ────────────────────── v3.2.4+0
#    Installed DocStringExtensions ────────────── v0.9.5
#    Installed Adapt ──────────────────────────── v4.3.0
#    Installed VectorizationBase ──────────────── v0.21.71
#    Installed ImageBase ──────────────────────── v0.1.7
#    Installed IntervalSets ───────────────────── v0.7.11
#    Installed IterTools ──────────────────────── v1.10.0
#    Installed ImageBinarization ──────────────── v0.3.1
#    Installed OpenJpeg_jll ───────────────────── v2.5.4+0
#    Installed IndirectArrays ─────────────────── v1.0.0
#    Installed Xorg_xtrans_jll ────────────────── v1.6.0+0
#    Installed SimpleWeightedGraphs ───────────── v1.5.0
#    Installed CPUSummary ─────────────────────── v0.2.6
#    Installed FixedPointNumbers ──────────────── v0.8.5
#    Installed ImageDistances ─────────────────── v0.2.17
#    Installed DataAPI ────────────────────────── v1.16.0
#    Installed RecipesBase ────────────────────── v1.3.4
#    Installed HostCPUFeatures ────────────────── v0.1.17
#    Installed libsixel_jll ───────────────────── v1.10.5+0
#    Installed Libglvnd_jll ───────────────────── v1.7.1+1
#    Installed AxisAlgorithms ─────────────────── v1.1.0
#    Installed Requires ───────────────────────── v1.3.1
#    Installed Xorg_libX11_jll ────────────────── v1.8.12+0
#    Installed ImageAxes ──────────────────────── v0.6.12
#    Installed Xorg_libXdmcp_jll ──────────────── v1.1.6+0
#    Installed FFTViews ───────────────────────── v0.3.2
#    Installed WoodburyMatrices ───────────────── v1.0.0
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed libwebp_jll ────────────────────── v1.4.0+0
#    Installed ImageMorphology ────────────────── v0.4.6
#    Installed SortingAlgorithms ──────────────── v1.2.2
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [916415d5] + Images v0.26.2
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [79e6a3ab] + Adapt v4.3.0
#   [66dad0bd] + AliasTables v1.1.3
#   [ec485272] + ArnoldiMethod v0.4.0
#   [4fba245c] + ArrayInterface v7.19.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [39de3d68] + AxisArrays v0.4.7
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [fa961155] + CEnum v0.5.0
#   [2a0fbf3d] + CPUSummary v0.2.6
#   [aafaddc9] + CatIndices v0.2.2
#   [d360d2e6] + ChainRulesCore v1.25.2
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [aaaa29a8] + Clustering v0.15.8
#   [35d6a980] + ColorSchemes v3.30.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [34da2185] + Compat v4.18.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [187b0558] + ConstructionBase v1.6.0
#   [150eb455] + CoordinateTransformations v0.6.4
#   [adafc99b] + CpuId v0.3.1
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [9a962f9c] + DataAPI v1.16.0
# ⌅ [864edb3b] + DataStructures v0.18.22
#   [b4f34e82] + Distances v0.10.12
#   [ffbed154] + DocStringExtensions v0.9.5
#   [4f61f5a4] + FFTViews v0.3.2
#   [7a1cc6ca] + FFTW v1.9.0
#   [5789e2e9] + FileIO v1.17.0
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [a2bd30eb] + Graphics v1.1.3
#   [86223c79] + Graphs v1.13.0
#   [076d061b] + HashArrayMappedTries v0.2.0
#   [2c695a8d] + HistogramThresholding v0.3.1
#   [3e5b6fbb] + HostCPUFeatures v0.1.17
#   [615f187c] + IfElse v0.1.1
#   [2803e5a7] + ImageAxes v0.6.12
#   [c817782e] + ImageBase v0.1.7
#   [cbc4b850] + ImageBinarization v0.3.1
#   [f332f351] + ImageContrastAdjustment v0.3.12
#   [a09fc81d] + ImageCore v0.10.5
#   [89d5987c] + ImageCorners v0.1.3
#   [51556ac3] + ImageDistances v0.2.17
#   [6a3955dd] + ImageFiltering v0.7.10
#   [82e4d734] + ImageIO v0.6.9
#   [6218d12a] + ImageMagick v1.4.2
#   [bc367c6b] + ImageMetadata v0.9.10
#   [787d08f9] + ImageMorphology v0.4.6
#   [2996bd0c] + ImageQualityIndexes v0.3.7
#   [80713f31] + ImageSegmentation v1.9.0
#   [4e3cecfd] + ImageShow v0.3.8
#   [02fcd773] + ImageTransformations v0.10.2
#   [916415d5] + Images v0.26.2
#   [9b13fd28] + IndirectArrays v1.0.0
#   [d25df0c9] + Inflate v0.1.5
#   [1d092043] + IntegralArrays v0.1.6
#   [a98d9a8b] + Interpolations v0.16.1
#   [8197267c] + IntervalSets v0.7.11
#   [92d709cd] + IrrationalConstants v0.2.4
#   [c8e1da08] + IterTools v1.10.0
#   [033835bb] + JLD2 v0.5.15
#   [692b3bcd] + JLLWrappers v1.7.1
#   [b835a17e] + JpegTurbo v0.1.6
#   [10f19ff3] + LayoutPointers v0.1.17
#   [8cdb02fc] + LazyModules v0.3.1
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [bdcacae8] + LoopVectorization v0.12.172
#   [1914dd2f] + MacroTools v0.5.16
#   [d125e4d3] + ManualMemory v0.1.8
#   [dbb5928d] + MappedArrays v0.4.2
#   [626554b9] + MetaGraphs v0.8.0
#   [e1d29d7a] + Missings v1.2.0
#   [e94cdb99] + MosaicViews v0.3.4
#   [77ba4419] + NaNMath v1.1.3
#   [b8a86587] + NearestNeighbors v0.4.22
#   [f09324ee] + Netpbm v1.1.1
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [52e1d378] + OpenEXR v0.3.3
#   [bac558e1] + OrderedCollections v1.8.1
#   [f57f5aa1] + PNGFiles v0.4.4
#   [5432bcbf] + PaddedViews v0.5.12
#   [d96e819e] + Parameters v0.12.3
#   [eebad327] + PkgVersion v0.3.3
#   [1d0040c9] + PolyesterWeave v0.2.2
#   [f27b6e38] + Polynomials v4.1.0
# ⌅ [aea7be01] + PrecompileTools v1.2.1
#   [21216c6a] + Preferences v1.4.3
#   [92933f4c] + ProgressMeter v1.10.4
#   [43287f4e] + PtrArrays v1.3.0
#   [4b34888f] + QOI v1.0.1
#   [94ee1d12] + Quaternions v0.7.6
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.5
#   [c1ae055f] + RealDot v0.1.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [189a3867] + Reexport v1.2.2
#   [dee08c22] + RegionTrees v0.3.2
#   [ae029012] + Requires v1.3.1
#   [6038ab10] + Rotations v1.7.1
#   [fdea26ae] + SIMD v3.7.1
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.43
#   [7e506255] + ScopedValues v1.4.0
#   [efcf1570] + Setfield v1.1.2
#   [699a6c99] + SimpleTraits v0.9.4
#   [47aef6b3] + SimpleWeightedGraphs v1.5.0
#   [45858cf5] + Sixel v0.1.5
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [cae243ae] + StackViews v0.1.2
#   [aedffcd0] + Static v1.2.0
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [90137ffa] + StaticArrays v1.9.14
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [10745b16] + Statistics v1.11.1
#   [82ae8749] + StatsAPI v1.7.1
#   [2913bbd2] + StatsBase v0.34.5
#   [62fd8b95] + TensorCore v0.1.1
#   [8290d209] + ThreadingUtilities v0.5.5
#   [731e570b] + TiffImages v0.11.4
#   [06e1c1a7] + TiledIteration v0.5.0
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.71
#   [e3aaa7dc] + WebP v0.1.3
#   [efce3f68] + WoodburyMatrices v1.0.0
#   [f5851436] + FFTW_jll v3.3.11+0
#   [61579ee1] + Ghostscript_jll v9.55.0+4
#   [59f7168a] + Giflib_jll v5.2.3+0
#   [c73af94c] + ImageMagick_jll v7.1.1048+0
#   [905a6f67] + Imath_jll v3.1.11+0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.2.0+0
#   [aacddb02] + JpegTurbo_jll v3.1.1+0
# ⌅ [88015f11] + LERC_jll v3.0.0+1
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
# ⌅ [89763e89] + Libtiff_jll v4.5.1+1
#   [d3a379c0] + LittleCMS_jll v2.16.0+0
#   [856f044c] + MKL_jll v2025.2.0+0
#   [18a262bb] + OpenEXR_jll v3.2.4+0
#   [643b3616] + OpenJpeg_jll v2.5.4+0
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.12+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.7+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [b53b4c65] + libpng_jll v1.6.50+0
#   [075b6546] + libsixel_jll v1.10.5+0
# ⌃ [c5f90fcd] + libwebp_jll v1.4.0+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [0dad84c5] + ArgTools v1.1.2
#   [56f22d72] + Artifacts v1.11.0
#   [2a0f44e3] + Base64 v1.11.0
#   [ade2ca70] + Dates v1.11.0
#   [8ba89e20] + Distributed v1.11.0
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching v1.11.0
#   [9fa8497b] + Future v1.11.0
#   [b77e0a4c] + InteractiveUtils v1.11.0
#   [4af54fe1] + LazyArtifacts v1.11.0
#   [b27032c2] + LibCURL v0.6.4
#   [76f85450] + LibGit2 v1.11.0
#   [8f399da3] + Libdl v1.11.0
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [56ddb016] + Logging v1.11.0
#   [d6f4376e] + Markdown v1.11.0
#   [a63ad114] + Mmap v1.11.0
#   [ca575930] + NetworkOptions v1.2.0
#   [44cfe95a] + Pkg v1.11.0
#   [de0858da] + Printf v1.11.0
#   [3fa0cd96] + REPL v1.11.0
#   [9a3f8284] + Random v1.11.0
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization v1.11.0
#   [1a1011a3] + SharedArrays v1.11.0
#   [6462fe0b] + Sockets v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [f489334b] + StyledStrings v1.11.0
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [cf7118a7] + UUIDs v1.11.0
#   [4ec0a83e] + Unicode v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [deac9b47] + LibCURL_jll v8.6.0+0
#   [e37daf67] + LibGit2_jll v1.7.2+0
#   [29816b5a] + LibSSH2_jll v1.11.0+1
#   [c8ffd9c3] + MbedTLS_jll v2.28.6+0
#   [14a3606d] + MozillaCACerts_jll v2023.12.12
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [05823500] + OpenLibm_jll v0.8.5+0
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#   [83775a58] + Zlib_jll v1.2.13+1
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
#   [8e850ede] + nghttp2_jll v1.59.0+0
#   [3f19e933] + p7zip_jll v17.4.0+2
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#    1397.4 ms  ✓ RangeArrays
#    1432.5 ms  ✓ AbstractFFTs
#    1146.8 ms  ✓ IndirectArrays
#    1087.1 ms  ✓ UnPack
#    1201.3 ms  ✓ CEnum
#    1227.5 ms  ✓ StatsAPI
#    1314.9 ms  ✓ TensorCore
#    1172.7 ms  ✓ ManualMemory
#    1363.4 ms  ✓ Statistics
#    1341.2 ms  ✓ IterTools
#    1554.0 ms  ✓ OrderedCollections
#    2252.6 ms  ✓ OffsetArrays
#     932.2 ms  ✓ Reexport
#    1235.6 ms  ✓ IntervalSets
#    1010.4 ms  ✓ SIMDTypes
#    1148.8 ms  ✓ RealDot
#    1037.6 ms  ✓ CustomUnitRanges
#    1079.6 ms  ✓ PtrArrays
#    1271.4 ms  ✓ Requires
#    1309.6 ms  ✓ DocStringExtensions
#    1059.0 ms  ✓ HashArrayMappedTries
#    1458.3 ms  ✓ TranscodingStreams
#    1030.3 ms  ✓ IfElse
#    1365.4 ms  ✓ MappedArrays
#    1480.8 ms  ✓ ComputationalResources
#    1212.4 ms  ✓ LazyModules
#    1169.0 ms  ✓ CommonWorldInvalidations
#    1399.0 ms  ✓ DataAPI
#    2846.3 ms  ✓ IrrationalConstants
#    1520.4 ms  ✓ NaNMath
#    1499.8 ms  ✓ Inflate
#    1498.6 ms  ✓ ConstructionBase
#    1453.3 ms  ✓ StaticArraysCore
#    4423.1 ms  ✓ MacroTools
#    1987.6 ms  ✓ ProgressMeter
#    1387.5 ms  ✓ JLLWrappers
#    1548.0 ms  ✓ Compat
#    1302.5 ms  ✓ Parameters
#    1840.7 ms  ✓ Statistics → SparseArraysExt
#    1866.2 ms  ✓ Distances
#    1820.3 ms  ✓ CpuId
#    1984.4 ms  ✓ WoodburyMatrices
#    1424.7 ms  ✓ StackViews
#    2155.0 ms  ✓ ThreadingUtilities
#    1118.6 ms  ✓ IntervalSets → IntervalSetsRandomExt
#    1255.5 ms  ✓ PaddedViews
#    1093.7 ms  ✓ Ratios
#    3476.4 ms  ✓ PkgVersion
#    1273.1 ms  ✓ IntervalSets → IntervalSetsStatisticsExt
#    1243.5 ms  ✓ CatIndices
#    1383.0 ms  ✓ AliasTables
#    1496.1 ms  ✓ Quaternions
#    1308.8 ms  ✓ Adapt
#    1115.3 ms  ✓ ScopedValues
#    3999.2 ms  ✓ RecipesBase
#    1306.5 ms  ✓ ConstructionBase → ConstructionBaseIntervalSetsExt
#    1327.6 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#    1464.8 ms  ✓ Missings
#    2263.6 ms  ✓ Static
#    4906.2 ms  ✓ FixedPointNumbers
#    1818.9 ms  ✓ LogExpFunctions
#    1726.2 ms  ✓ Xorg_libXau_jll
#    1955.5 ms  ✓ SimpleTraits
#    1772.9 ms  ✓ libpng_jll
#    1626.1 ms  ✓ Imath_jll
#    1626.5 ms  ✓ Giflib_jll
#    1604.3 ms  ✓ LERC_jll
#    3073.3 ms  ✓ Ghostscript_jll
#    1823.0 ms  ✓ JpegTurbo_jll
#    1847.7 ms  ✓ XZ_jll
#    1570.1 ms  ✓ Xorg_libXdmcp_jll
#    1805.7 ms  ✓ oneTBB_jll
#    1710.3 ms  ✓ Zstd_jll
#    1100.9 ms  ✓ Compat → CompatLinearAlgebraExt
#    1334.8 ms  ✓ Xorg_xtrans_jll
#    1602.5 ms  ✓ FFTW_jll
#    1708.5 ms  ✓ Distances → DistancesSparseArraysExt
#    3553.2 ms  ✓ IntelOpenMP_jll
#    1242.2 ms  ✓ MosaicViews
#    1755.5 ms  ✓ AxisAlgorithms
#    1521.3 ms  ✓ Adapt → AdaptSparseArraysExt
#    1387.1 ms  ✓ ArrayInterface
#    1205.6 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#    1996.5 ms  ✓ AxisArrays
#    1259.6 ms  ✓ BitTwiddlingConvenienceFunctions
#    1945.4 ms  ✓ IntervalSets → IntervalSetsRecipesBaseExt
#    1258.7 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#    1480.6 ms  ✓ Xorg_libxcb_jll
#    8762.5 ms  ✓ FileIO
#    2095.6 ms  ✓ OpenEXR_jll
#    2134.5 ms  ✓ libsixel_jll
#    2861.1 ms  ✓ Setfield
#    2771.7 ms  ✓ CPUSummary
#    2074.0 ms  ✓ Libtiff_jll
#    1035.4 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    3423.7 ms  ✓ ColorTypes
#    1477.5 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#    1275.8 ms  ✓ Xorg_libX11_jll
#    1945.7 ms  ✓ HostCPUFeatures
#    3418.7 ms  ✓ ChainRulesCore
#    1699.5 ms  ✓ PolyesterWeave
#    1328.3 ms  ✓ IntegralArrays
#    3498.3 ms  ✓ StaticArrayInterface
#    1934.6 ms  ✓ LittleCMS_jll
#    4053.2 ms  ✓ DataStructures
#    1815.0 ms  ✓ Xorg_libXext_jll
#    2077.3 ms  ✓ ColorTypes → StyledStringsExt
#   15904.5 ms  ✓ SIMD
#    2247.7 ms  ✓ Distances → DistancesChainRulesCoreExt
#    2282.3 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    2508.0 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    4712.6 ms  ✓ QOI
#    1406.9 ms  ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#    1712.5 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#    4337.4 ms  ✓ ColorVectorSpace
#    1541.4 ms  ✓ CloseOpenIntervals
#    8562.5 ms  ✓ MKL_jll
#    2344.6 ms  ✓ LayoutPointers
#    2372.6 ms  ✓ OpenJpeg_jll
#    1501.3 ms  ✓ Libglvnd_jll
#   15581.8 ms  ✓ StaticArrays
#    1755.2 ms  ✓ SortingAlgorithms
#    1864.7 ms  ✓ TiledIteration
#    3704.4 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    2051.6 ms  ✓ ImageMagick_jll
#    2158.2 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    2336.0 ms  ✓ libwebp_jll
#    2033.5 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    2238.0 ms  ✓ RegionTrees
#    2713.7 ms  ✓ CoordinateTransformations
#    3544.1 ms  ✓ ArnoldiMethod
#    9310.8 ms  ✓ Colors
#    2075.9 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    1961.5 ms  ✓ Adapt → AdaptStaticArraysExt
#    2285.9 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#    1521.4 ms  ✓ Graphics
#    4690.2 ms  ✓ Rotations
#    5546.1 ms  ✓ StatsBase
#    4246.5 ms  ✓ OpenEXR
#    5523.7 ms  ✓ NearestNeighbors
#    2898.0 ms  ✓ Rotations → RotationsRecipesBaseExt
#    6322.8 ms  ✓ Interpolations
#   12700.3 ms  ✓ FFTW
#    6104.8 ms  ✓ Clustering
#   10912.4 ms  ✓ Graphs
#    3199.7 ms  ✓ FFTViews
#   11124.3 ms  ✓ ColorSchemes
#   16809.4 ms  ✓ VectorizationBase
#    3416.5 ms  ✓ SimpleWeightedGraphs
#    2141.3 ms  ✓ SLEEFPirates
#   34329.8 ms  ✓ Polynomials
#    2299.5 ms  ✓ Polynomials → PolynomialsFFTWExt
#    2407.1 ms  ✓ Polynomials → PolynomialsChainRulesCoreExt
#   28406.2 ms  ✓ ImageCore
#    6074.9 ms  ✓ ImageBase
#    8218.7 ms  ✓ WebP
#    4380.4 ms  ✓ HistogramThresholding
#   10686.3 ms  ✓ JpegTurbo
#   10793.9 ms  ✓ PNGFiles
#   11200.5 ms  ✓ Sixel
#   12087.7 ms  ✓ ImageMagick
#    6088.9 ms  ✓ ImageShow
#    6514.2 ms  ✓ ImageAxes
#   53175.1 ms  ✓ JLD2
#    7308.2 ms  ✓ ImageTransformations
#    4295.9 ms  ✓ ImageMetadata
#    6761.3 ms  ✓ ImageBinarization
#    5320.0 ms  ✓ JLD2 → UnPackExt
#    7416.8 ms  ✓ MetaGraphs
#   55220.4 ms  ✓ TiffImages
#    7871.8 ms  ✓ ImageContrastAdjustment
#    5412.1 ms  ✓ Netpbm
#   38563.6 ms  ✓ LoopVectorization
#    2777.3 ms  ✓ ImageIO
#    5094.4 ms  ✓ ImageMorphology
#    2359.2 ms  ✓ ImageDistances
#   56342.8 ms  ✓ ImageFiltering
#    7101.8 ms  ✓ ImageSegmentation
#   11295.1 ms  ✓ ImageCorners
#   14366.9 ms  ✓ ImageQualityIndexes
#    6342.7 ms  ✓ Images
#   181 dependencies successfully precompiled in 144 seconds. 39 already precompiled.
#   1 dependency had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: IntelOpenMP
# └
#    Resolving package versions...
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [3da002f7] + ColorTypes v0.12.1
#   No Changes to `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`

# %%
Pkg.add("Plots")
Pkg.add("Clustering")
Pkg.add("Statistics")
# Out:
#    Resolving package versions...
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed GR_jll ─────────────────────── v0.73.7+0
#    Installed Opus_jll ───────────────────── v1.5.2+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed LoggingExtras ──────────────── v1.1.0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed Libmount_jll ───────────────── v2.41.0+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Measures ───────────────────── v0.3.2
#    Installed Unitful ────────────────────── v1.24.0
#    Installed Contour ────────────────────── v0.6.3
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed PlotUtils ──────────────────── v1.4.3
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed Cairo_jll ──────────────────── v1.18.5+0
#    Installed OpenSSL ────────────────────── v1.5.0
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed HTTP ───────────────────────── v1.10.17
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Fontconfig_jll ─────────────── v2.16.0+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.6+0
#    Installed FFMPEG ─────────────────────── v0.4.4
#    Installed Showoff ────────────────────── v1.0.3
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed Pango_jll ──────────────────── v1.56.3+0
#    Installed GR ─────────────────────────── v0.73.7
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed JSON ───────────────────────── v0.21.4
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed xkbcommon_jll ──────────────── v1.9.2+0
#    Installed Bzip2_jll ──────────────────── v1.0.9+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed x264_jll ───────────────────── v10164.0.1+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed MbedTLS ────────────────────── v1.1.9
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed CodecZlib ──────────────────── v0.7.8
#    Installed libaom_jll ─────────────────── v3.12.1+0
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed Scratch ────────────────────── v1.3.0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.5+0
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed Parsers ────────────────────── v2.8.3
#    Installed Format ─────────────────────── v1.3.7
#    Installed Expat_jll ──────────────────── v2.6.5+0
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed Plots ──────────────────────── v1.40.17
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.7.1+1
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed Qt6Declarative_jll ─────────── v6.7.1+2
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed StableRNGs ─────────────────── v1.0.3
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed Libuuid_jll ────────────────── v2.41.0+0
#    Installed libass_jll ─────────────────── v0.17.4+0
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed Latexify ───────────────────── v0.16.8
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed OpenSSL_jll ────────────────── v3.5.1+0
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed FFMPEG_jll ─────────────────── v7.1.1+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed Xorg_libXfixes_jll ─────────── v6.0.1+0
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed Qt6Wayland_jll ─────────────── v6.7.1+1
#    Installed GettextRuntime_jll ─────────── v0.22.4+0
#    Installed Qt6Base_jll ────────────────── v6.7.1+1
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed LaTeXStrings ───────────────── v1.4.0
#    Installed URIs ───────────────────────── v1.6.1
#    Installed Glib_jll ───────────────────── v2.84.3+0
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed UnitfulLatexify ────────────── v1.7.0
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [91a5bcdd] + Plots v1.40.17
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`
#   [d1d4a3ce] + BitFlags v0.1.9
#   [944b1d66] + CodecZlib v0.7.8
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.4
#   [1fa38f19] + Format v1.3.7
# ⌃ [28b8d3ca] + GR v0.73.7
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.17
#   [1019f520] + JLFzf v0.1.11
#   [682c06a0] + JSON v0.21.4
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [23fbe1c1] + Latexify v0.16.8
#   [e6f89c97] + LoggingExtras v1.1.0
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.2
#   [4d8831e6] + OpenSSL v1.5.0
#   [69de0a69] + Parsers v2.8.3
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.17
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [6c6a2e73] + Scratch v1.3.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [860ef19b] + StableRNGs v1.0.3
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.24.0
#   [45397f5d] + UnitfulLatexify v1.7.0
#   [41fe7b60] + Unzip v0.2.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.6.5+0
#   [b22a6f82] + FFMPEG_jll v7.1.1+0
#   [a3f928ae] + Fontconfig_jll v2.16.0+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
# ⌅ [d2c73de3] + GR_jll v0.73.7+0
#   [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [7746bdde] + Glib_jll v2.84.3+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
#   [e9f186c6] + Libffi_jll v3.4.7+0
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.0+0
#   [38a345b3] + Libuuid_jll v2.41.0+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [458c3c95] + OpenSSL_jll v3.5.1+0
#   [91d4177d] + Opus_jll v1.5.2+0
#   [36c8627f] + Pango_jll v1.56.3+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
# ⌅ [c0090381] + Qt6Base_jll v6.7.1+1
# ⌅ [629bc702] + Qt6Declarative_jll v6.7.1+2
# ⌅ [ce943373] + Qt6ShaderTools_jll v6.7.1+1
# ⌃ [e99dba38] + Qt6Wayland_jll v6.7.1+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.1+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.6+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.5+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.12.1+0
#   [0ac62f75] + libass_jll v0.17.4+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
#   [1270edf5] + x264_jll v10164.0.1+0
#   [dfaa095f] + x265_jll v4.1.0+0
#   [d8fb68d0] + xkbcommon_jll v1.9.2+0
#   [8dfed614] + Test v1.11.0
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#    1341.9 ms  ✓ LaTeXStrings
#    1694.2 ms  ✓ ConcurrentUtilities
#    1838.4 ms  ✓ Grisu
#    1310.5 ms  ✓ SimpleBufferStream
#    1392.1 ms  ✓ BitFlags
#    1592.3 ms  ✓ Contour
#    1561.0 ms  ✓ Measures
#    1577.6 ms  ✓ StableRNGs
#    1510.1 ms  ✓ DelimitedFiles
#    1545.0 ms  ✓ CodecZlib
#    1651.2 ms  ✓ Unzip
#    1787.8 ms  ✓ URIs
#    2112.1 ms  ✓ Format
#     896.4 ms  ✓ Scratch
#    1156.6 ms  ✓ LoggingExtras
#    1129.6 ms  ✓ Libmount_jll
#    1336.9 ms  ✓ Bzip2_jll
#    1184.2 ms  ✓ EpollShim_jll
#    1282.2 ms  ✓ Graphite2_jll
#    1415.4 ms  ✓ OpenSSL_jll
#    1360.5 ms  ✓ LLVMOpenMP_jll
#    1548.1 ms  ✓ ExceptionUnwrapping
#    2016.8 ms  ✓ MbedTLS
#    1097.4 ms  ✓ Xorg_libICE_jll
#    1269.1 ms  ✓ mtdev_jll
#    1568.6 ms  ✓ x264_jll
#    3291.4 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#    1578.8 ms  ✓ libaom_jll
#    1456.1 ms  ✓ libfdk_aac_jll
#    1452.9 ms  ✓ fzf_jll
#    1502.2 ms  ✓ LAME_jll
#    1457.9 ms  ✓ Ogg_jll
#    1578.5 ms  ✓ x265_jll
#    1403.1 ms  ✓ Expat_jll
#    1410.3 ms  ✓ LZO_jll
#    3408.8 ms  ✓ UnicodeFun
#    1143.4 ms  ✓ libevdev_jll
#    1238.0 ms  ✓ eudev_jll
#    1245.1 ms  ✓ Libuuid_jll
#    1398.1 ms  ✓ Opus_jll
#    1445.4 ms  ✓ Xorg_xcb_util_jll
#    1532.8 ms  ✓ Libffi_jll
#    1426.1 ms  ✓ Xorg_libXrender_jll
#    1549.6 ms  ✓ Libiconv_jll
#    1407.2 ms  ✓ Xorg_libXfixes_jll
#    1384.4 ms  ✓ Xorg_libxkbfile_jll
#    1491.1 ms  ✓ FriBidi_jll
#     882.0 ms  ✓ Showoff
#     988.7 ms  ✓ RelocatableFolders
#    1050.5 ms  ✓ Xorg_libXinerama_jll
#    1037.6 ms  ✓ Xorg_libSM_jll
#    1241.8 ms  ✓ Pixman_jll
#    1355.5 ms  ✓ FreeType2_jll
#    1417.5 ms  ✓ libvorbis_jll
#    1159.1 ms  ✓ Dbus_jll
#    1175.7 ms  ✓ libinput_jll
#    1170.1 ms  ✓ Xorg_xcb_util_image_jll
#    1211.5 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1224.8 ms  ✓ Xorg_xcb_util_renderutil_jll
#    2423.3 ms  ✓ JLFzf
#    1278.1 ms  ✓ Xorg_xcb_util_wm_jll
#    1231.0 ms  ✓ Wayland_jll
#    1247.7 ms  ✓ Xorg_libXrandr_jll
#    3367.8 ms  ✓ OpenSSL
#    1194.4 ms  ✓ Xorg_libXcursor_jll
#    1188.7 ms  ✓ Xorg_libXi_jll
#    1128.5 ms  ✓ Xorg_xkbcomp_jll
#    1619.4 ms  ✓ GettextRuntime_jll
#    1165.2 ms  ✓ Xorg_xcb_util_cursor_jll
#    1781.2 ms  ✓ Fontconfig_jll
#    1042.3 ms  ✓ Xorg_xkeyboard_config_jll
#    5278.4 ms  ✓ Latexify
#    1521.3 ms  ✓ Glib_jll
#     863.9 ms  ✓ xkbcommon_jll
#    1099.4 ms  ✓ Latexify → SparseArraysExt
#     891.2 ms  ✓ Vulkan_Loader_jll
#    1388.7 ms  ✓ Cairo_jll
#    1299.1 ms  ✓ HarfBuzz_jll
#    1950.1 ms  ✓ Qt6Base_jll
#    1380.3 ms  ✓ libass_jll
#    1473.6 ms  ✓ Pango_jll
#    1574.0 ms  ✓ Qt6ShaderTools_jll
#     839.0 ms  ✓ libdecor_jll
#    1080.0 ms  ✓ GLFW_jll
#    2032.1 ms  ✓ FFMPEG_jll
#    2706.0 ms  ✓ FFMPEG
#    4626.8 ms  ✓ Qt6Declarative_jll
#    3165.6 ms  ✓ GR_jll
#   15225.3 ms  ✓ PlotUtils
#   16729.0 ms  ✓ Parsers
#     685.5 ms  ✓ Qt6Wayland_jll
#    1761.5 ms  ✓ JSON
#    3380.9 ms  ✓ PlotThemes
#    4741.3 ms  ✓ RecipesPipeline
#   26604.8 ms  ✓ Unitful
#    1566.8 ms  ✓ Unitful → ConstructionBaseUnitfulExt
#    1889.2 ms  ✓ Unitful → PrintfExt
#    2853.7 ms  ✓ Interpolations → InterpolationsUnitfulExt
#   21146.4 ms  ✓ HTTP
#    1902.0 ms  ✓ UnitfulLatexify
#    3235.3 ms  ✓ FileIO → HTTPExt
#    3654.3 ms  ✓ GR
#   45730.1 ms  ✓ Plots
#    4128.9 ms  ✓ Plots → UnitfulExt
#    4119.5 ms  ✓ Plots → FileIOExt
#   105 dependencies successfully precompiled in 86 seconds. 222 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [aaaa29a8] + Clustering v0.15.8
#   No Changes to `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [10745b16] + Statistics v1.11.1
#   No Changes to `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`

# %%
Pkg.add("Interpolations")
Pkg.add("FileIO")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [a98d9a8b] + Interpolations v0.16.1
#   No Changes to `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [5789e2e9] + FileIO v1.17.0
#   No Changes to `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`

# %%
# collect all the required packages here
using Images #this is needed for reading the Images
using Plots #this is needed for plotting and visualisation

using Clustering #this is needed for clustering
using Interpolations #this is needed for interpolation
using FileIO #this is needed for reading and writing files
using ColorTypes #this is needed for color manipulation
using Statistics #this is needed for statistical analysis

Pkg.add("PyPlot") #this is needed for plotting and visualisation
using PyPlot #this is needed for plotting and visualisation ~
# Out:
#    Resolving package versions...
#    Installed PyCall ───────── v1.96.4
#    Installed PyPlot ───────── v2.11.6
#    Installed VersionParsing ─ v1.3.0
#    Installed Conda ────────── v1.10.2
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Project.toml`
#   [d330b81b] + PyPlot v2.11.6
#     Updating `C:\Users\2572664c\.julia\environments\v1.11\Manifest.toml`
#   [8f4d0f93] + Conda v1.10.2
#   [438e738f] + PyCall v1.96.4
#   [d330b81b] + PyPlot v2.11.6
#   [81def892] + VersionParsing v1.3.0
#     Building Conda ─→ `C:\Users\2572664c\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\b19db3927f0db4151cb86d073689f2428e524576\build.log`
#     Building PyCall → `C:\Users\2572664c\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9816a3826b0ebf49ab4926e2b18842ad8b5c8f04\build.log`
# Precompiling project...
#     690.8 ms  ✓ VersionParsing
#     934.4 ms  ✓ Conda
#    8233.3 ms  ✓ PyCall
#    2537.9 ms  ✓ PyPlot
#   4 dependencies successfully precompiled in 13 seconds. 327 already precompiled.
# ┌ Info: Installing matplotlib via the Conda matplotlib package...
# └ @ PyCall C:\Users\2572664c\.julia\packages\PyCall\1gn3u\src\PyCall.jl:719
# ┌ Info: Running `conda install -y matplotlib` in root environment
# └ @ Conda C:\Users\2572664c\.julia\packages\Conda\zReqD\src\Conda.jl:181
# Channels:
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
# ## Package Plan ##
#
#   environment location: C:\Users\2572664c\.julia\conda\3\x86_64
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          48 KB  conda-forge
#     brotli-1.1.0               |       h2466b09_3          20 KB  conda-forge
#     brotli-bin-1.1.0           |       h2466b09_3          21 KB  conda-forge
#     cairo-1.18.4               |       h5782bbf_0         1.5 MB  conda-forge
#     contourpy-1.3.3            |  py312hf90b1b7_1         218 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     double-conversion-3.3.1    |       he0c23c2_0          70 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h765892d_1         188 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.59.0           |  py312h05f76fc_0         2.3 MB  conda-forge
#     freetype-2.13.3            |       h57928b3_1         180 KB  conda-forge
#     graphite2-1.3.14           |       hac47afa_1         126 KB  conda-forge
#     harfbuzz-11.3.3            |       h8796e6f_0         1.1 MB  conda-forge
#     icu-75.1                   |       he0c23c2_0        13.9 MB  conda-forge
#     kiwisolver-1.4.8           |  py312hf90b1b7_1          71 KB  conda-forge
#     lcms2-2.17                 |       hbcf6048_0         499 KB  conda-forge
#     lerc-4.0.0                 |       h6470a55_1         161 KB  conda-forge
#     libbrotlicommon-1.1.0      |       h2466b09_3          70 KB  conda-forge
#     libbrotlidec-1.1.0         |       h2466b09_3          33 KB  conda-forge
#     libbrotlienc-1.1.0         |       h2466b09_3         240 KB  conda-forge
#     libclang13-20.1.8          |default_hadf22e1_0        27.0 MB  conda-forge
#     libdeflate-1.24            |       h76ddb4d_0         153 KB  conda-forge
#     libfreetype-2.13.3         |       h57928b3_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h0b5ce68_1         329 KB  conda-forge
#     libgcc-15.1.0              |       h1383e82_4         653 KB  conda-forge
#     libglib-2.84.3             |       h1c1036b_0         3.6 MB  conda-forge
#     libgomp-15.1.0             |       h1383e82_4         523 KB  conda-forge
#     libintl-0.22.5             |       h5728263_3          93 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       h2466b09_0         819 KB  conda-forge
#     libpng-1.6.50              |       h7351971_1         374 KB  conda-forge
#     libtiff-4.7.0              |       h05922d8_5         956 KB  conda-forge
#     libwebp-base-1.6.0         |       h4d5522a_0         273 KB  conda-forge
#     libxcb-1.17.0              |       h0e4246c_0         1.2 MB  conda-forge
#     libxslt-1.1.43             |       h25c3957_0         407 KB  conda-forge
#     matplotlib-3.10.5          |  py312h2e8e312_0          17 KB  conda-forge
#     matplotlib-base-3.10.5     |  py312h0ebf65c_0         7.6 MB  conda-forge
#     munkres-1.1.4              |     pyhd8ed1ab_1          15 KB  conda-forge
#     openjpeg-2.5.3             |       h24db6dd_1         239 KB  conda-forge
#     pcre2-10.45                |       h99c9b8b_0        1016 KB  conda-forge
#     pillow-11.3.0              |  py312hfb502af_0        40.8 MB  conda-forge
#     pixman-0.46.4              |       hc614b68_0         470 KB  conda-forge
#     pthread-stubs-0.4          |    h0e40799_1002           9 KB  conda-forge
#     pyparsing-3.2.3            |     pyhe01879c_2         100 KB  conda-forge
#     pyside6-6.9.1              |  py312h0ba07f7_0         8.5 MB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhe01879c_2         228 KB  conda-forge
#     qhull-2020.2               |       hc790b64_5         1.3 MB  conda-forge
#     qt6-main-6.9.1             |       h02ddd7d_2        90.1 MB  conda-forge
#     six-1.17.0                 |     pyhe01879c_1          18 KB  conda-forge
#     tornado-6.5.1              |  py312h4389bb4_0         833 KB  conda-forge
#     unicodedata2-16.0.0        |  py312h4389bb4_0         392 KB  conda-forge
#     xorg-libxau-1.0.12         |       h0e40799_0         105 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       h0e40799_0          68 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       211.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/win-64::_openmp_mutex-4.5-2_gnu
#   brotli             conda-forge/win-64::brotli-1.1.0-h2466b09_3
#   brotli-bin         conda-forge/win-64::brotli-bin-1.1.0-h2466b09_3
#   cairo              conda-forge/win-64::cairo-1.18.4-h5782bbf_0
#   contourpy          conda-forge/win-64::contourpy-1.3.3-py312hf90b1b7_1
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   double-conversion  conda-forge/win-64::double-conversion-3.3.1-he0c23c2_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/win-64::fontconfig-2.15.0-h765892d_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/win-64::fonttools-4.59.0-py312h05f76fc_0
#   freetype           conda-forge/win-64::freetype-2.13.3-h57928b3_1
#   graphite2          conda-forge/win-64::graphite2-1.3.14-hac47afa_1
#   harfbuzz           conda-forge/win-64::harfbuzz-11.3.3-h8796e6f_0
#   icu                conda-forge/win-64::icu-75.1-he0c23c2_0
#   kiwisolver         conda-forge/win-64::kiwisolver-1.4.8-py312hf90b1b7_1
#   lcms2              conda-forge/win-64::lcms2-2.17-hbcf6048_0
#   lerc               conda-forge/win-64::lerc-4.0.0-h6470a55_1
#   libbrotlicommon    conda-forge/win-64::libbrotlicommon-1.1.0-h2466b09_3
#   libbrotlidec       conda-forge/win-64::libbrotlidec-1.1.0-h2466b09_3
#   libbrotlienc       conda-forge/win-64::libbrotlienc-1.1.0-h2466b09_3
#   libclang13         conda-forge/win-64::libclang13-20.1.8-default_hadf22e1_0
#   libdeflate         conda-forge/win-64::libdeflate-1.24-h76ddb4d_0
#   libfreetype        conda-forge/win-64::libfreetype-2.13.3-h57928b3_1
#   libfreetype6       conda-forge/win-64::libfreetype6-2.13.3-h0b5ce68_1
#   libgcc             conda-forge/win-64::libgcc-15.1.0-h1383e82_4
#   libglib            conda-forge/win-64::libglib-2.84.3-h1c1036b_0
#   libgomp            conda-forge/win-64::libgomp-15.1.0-h1383e82_4
#   libintl            conda-forge/win-64::libintl-0.22.5-h5728263_3
#   libjpeg-turbo      conda-forge/win-64::libjpeg-turbo-3.1.0-h2466b09_0
#   libpng             conda-forge/win-64::libpng-1.6.50-h7351971_1
#   libtiff            conda-forge/win-64::libtiff-4.7.0-h05922d8_5
#   libwebp-base       conda-forge/win-64::libwebp-base-1.6.0-h4d5522a_0
#   libxcb             conda-forge/win-64::libxcb-1.17.0-h0e4246c_0
#   libxslt            conda-forge/win-64::libxslt-1.1.43-h25c3957_0
#   matplotlib         conda-forge/win-64::matplotlib-3.10.5-py312h2e8e312_0
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.10.5-py312h0ebf65c_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyhd8ed1ab_1
#   openjpeg           conda-forge/win-64::openjpeg-2.5.3-h24db6dd_1
#   pcre2              conda-forge/win-64::pcre2-10.45-h99c9b8b_0
#   pillow             conda-forge/win-64::pillow-11.3.0-py312hfb502af_0
#   pixman             conda-forge/win-64::pixman-0.46.4-hc614b68_0
#   pthread-stubs      conda-forge/win-64::pthread-stubs-0.4-h0e40799_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.3-pyhe01879c_2
#   pyside6            conda-forge/win-64::pyside6-6.9.1-py312h0ba07f7_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhe01879c_2
#   qhull              conda-forge/win-64::qhull-2020.2-hc790b64_5
#   qt6-main           conda-forge/win-64::qt6-main-6.9.1-h02ddd7d_2
#   six                conda-forge/noarch::six-1.17.0-pyhe01879c_1
#   tornado            conda-forge/win-64::tornado-6.5.1-py312h4389bb4_0
#   unicodedata2       conda-forge/win-64::unicodedata2-16.0.0-py312h4389bb4_0
#   xorg-libxau        conda-forge/win-64::xorg-libxau-1.0.12-h0e40799_0
#   xorg-libxdmcp      conda-forge/win-64::xorg-libxdmcp-1.1.5-h0e40799_0
#
#
#
# qt6-main-6.9.1       | 90.1 MB   |            |   0%
# pillow-11.3.0        | 40.8 MB   |            |   0%
#
# libclang13-20.1.8    | 27.0 MB   |            |   0%
#
#
# icu-75.1             | 13.9 MB   |            |   0%
#
#
#
# pyside6-6.9.1        | 8.5 MB    |            |   0%
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    |            |   0%
#
#
#
#
#
# libglib-2.84.3       | 3.6 MB    |            |   0%
#
#
#
#
#
#
# fonttools-4.59.0     | 2.3 MB    |            |   0%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.45          | 1016 KB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.5.1        | 833 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-15.1.0        | 653 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   |            |   0% [A
# pillow-11.3.0        | 40.8 MB   |            |   0%
#
# libclang13-20.1.8    | 27.0 MB   | 3          |   3%
#
#
# icu-75.1             | 13.9 MB   | 1          |   2%
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | 1          |   2%
# pillow-11.3.0        | 40.8 MB   | 1          |   1%
#
# libclang13-20.1.8    | 27.0 MB   | #5         |  16%
#
#
# icu-75.1             | 13.9 MB   | #          |  11%
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | 4          |   5%
#
# libclang13-20.1.8    | 27.0 MB   | ###        |  31%
# pillow-11.3.0        | 40.8 MB   | 4          |   4%
#
#
# icu-75.1             | 13.9 MB   | ##7        |  27%
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | 6          |   7%
#
# libclang13-20.1.8    | 27.0 MB   | ####3      |  44%
#
#
# icu-75.1             | 13.9 MB   | ####1      |  41%
# pillow-11.3.0        | 40.8 MB   | 6          |   7%
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | 9          |  10%
#
# libclang13-20.1.8    | 27.0 MB   | #####8     |  59%
# pillow-11.3.0        | 40.8 MB   | #          |  10%
#
#
# icu-75.1             | 13.9 MB   | #####2     |  52%
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | #2         |  12%
#
# libclang13-20.1.8    | 27.0 MB   | #######    |  71%
# pillow-11.3.0        | 40.8 MB   | #4         |  14%
#
#
# icu-75.1             | 13.9 MB   | ######4    |  65%
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | #4         |  15%
#
# libclang13-20.1.8    | 27.0 MB   | ########3  |  83%
# pillow-11.3.0        | 40.8 MB   | #8         |  19%
#
#
#
# pyside6-6.9.1        | 8.5 MB    | ######     |  61%
#
#
# qt6-main-6.9.1       | 90.1 MB   | #7         |  17%
# pillow-11.3.0        | 40.8 MB   | ##2        |  23%
#
#
#
# pyside6-6.9.1        | 8.5 MB    | #######9   |  79%
#
# libclang13-20.1.8    | 27.0 MB   | #########5 |  95%
#
#
# qt6-main-6.9.1       | 90.1 MB   | ##         |  21%
# pillow-11.3.0        | 40.8 MB   | ##7        |  27%
#
#
#
# pyside6-6.9.1        | 8.5 MB    | #########4 |  94%
#
# libclang13-20.1.8    | 27.0 MB   | ########## | 100%
#
#
# icu-75.1             | 13.9 MB   | ########## | 100%
#
#
# qt6-main-6.9.1       | 90.1 MB   | ##8        |  29%
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    |            |   0%
#
#
#
# pyside6-6.9.1        | 8.5 MB    | ########## | 100%
#
#
#
#
#
# libglib-2.84.3       | 3.6 MB    |            |   0%
# pillow-11.3.0        | 40.8 MB   | ###        |  31%
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | ###3       |  33%
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##8        |  29%
#
#
#
#
#
# libglib-2.84.3       | 3.6 MB    | ##8        |  29%
#
#
#
#
#
#
# fonttools-4.59.0     | 2.3 MB    | ###7       |  37%
# qt6-main-6.9.1       | 90.1 MB   | ###7       |  38%
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ######5    |  65%
#
#
#
#
#
# libglib-2.84.3       | 3.6 MB    | #####6     |  56%
#
#
#
#
#
#
# fonttools-4.59.0     | 2.3 MB    | #########2 |  92%
# qt6-main-6.9.1       | 90.1 MB   | ####2      |  42%
#
#
#
#
#
# libglib-2.84.3       | 3.6 MB    | #########5 |  96%
#
#
#
#
#
#
# fonttools-4.59.0     | 2.3 MB    | ########## | 100%
# pillow-11.3.0        | 40.8 MB   | ####4      |  45%
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | ####6      |  47%
#
#
#
#
#
# libglib-2.84.3       | 3.6 MB    | ########## | 100%
# pillow-11.3.0        | 40.8 MB   | #####1     |  52%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | #####1     |  51%
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | 1          |   1%
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########## | 100%
# pillow-11.3.0        | 40.8 MB   | ######     |  60%
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 1.5 MB    | #2         |  13%
# pillow-11.3.0        | 40.8 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | #####9     |  59%
# pillow-11.3.0        | 40.8 MB   | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | 1          |   2%
# pillow-11.3.0        | 40.8 MB   | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.5.1        | 833 KB    | 1          |   2%
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 1.5 MB    | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | ########## | 100%
# pillow-11.3.0        | 40.8 MB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | 2          |   2%
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-15.1.0        | 653 KB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qt6-main-6.9.1       | 90.1 MB   | #########4 |  94%
# pillow-11.3.0        | 40.8 MB   | ########## | 100%
#
#
# icu-75.1             | 13.9 MB   | ########## | 100%
#
#
#
# pyside6-6.9.1        | 8.5 MB    | ########## | 100%
#
# qt6-main-6.9.1       | 90.1 MB   | ########## | 100%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
#
#
#
#
# libglib-2.84.3       | 3.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | ########## | 100%
#
#
#
#
#
#
# fonttools-4.59.0     | 2.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-11.3.3      | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.45          | 1016 KB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.45          | 1016 KB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.5.1        | 833 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.5.1        | 833 KB    | ########## | 100%
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 819 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-15.1.0        | 653 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-15.1.0        | 653 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | ########## | 100%
# qt6-main-6.9.1       | 90.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                      A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Matplotlib is building the font cache; this may take a moment.

# %%
# ***** RUN 2D MODEL FROM IMAGE ***********************************

# Clear workspace equivalent
using LinearAlgebra
using Statistics

# Declare test and conservation flags
const TEST = "NO"
const conservation = "NO"

# Load model setup from image, interpolate to target grid size
h = W / Nx        # grid spacing
n_units = 7       # number of rock units in image


# Sediment parameters
#rho_particle = 2650.0    # [kg/m³]
#rho_air = 1.225          # [kg/m³]
#sa_phi = 0.23
#gr_phi = 0.34
#si_phi = 0.15

rho_sand = (1 - sa_phi) * rho_particle + sa_phi * rho_air
rho_grav = (1 - gr_phi) * rho_particle + gr_phi * rho_air
rho_silt = (1 - si_phi) * rho_particle + si_phi * rho_air

# Material properties: [kT, rho0, Cp, Hr]
matprop = [
 #   kT      rho0       Cp        Hr          # Material properties   
 1   1e-6    1           1000      0             # Sky 
 2   2.467   2700.0       874.5    2.9e-6       # Yellow: Mylonite 
 3   3.218   2703.5      1000      5.575e-6     # Red :Corodale Gneiss 
 4   0.25    rho_sand     932      1e-6         # Orange: Crushged and Altered Corodale Gneiss 
 5   0.65    rho_grav     566      1e-6         # Green: Corodale Gneiss
 6   1.3     2091.8       878      1e-6         # Purple: Pseudotachylite  
 7   0.39    rho_silt    1088      1e-6         # Lilac: Basement Gneiss  

]

# Get coefficient fields
if TEST == "YES"
    rho0 = fill(2400.0, Nz, Nx)
    Cp   = fill(1000.0, Nz, Nx)
    sigma = fill(1000.0, Nz, Nx)
    Hr   = ones(Nz, Nx)
    air  = units .== 1
    t_gradient = 35 / 1000
    geotherm = [0.0, t_gradient]
else
    
    rho0 = reshape([matprop[u, 2] for u in units], Nz, Nx)
    Cp   = reshape([matprop[u, 3] for u in units], Nz, Nx)
    sigma = reshape([matprop[u, 1] for u in units], Nz, Nx)
    Hr   = reshape([matprop[u, 4] for u in units], Nz, Nx)
    air  = units .== 1
    t_gradient = 35 / 1000
    geotherm = [0.0, t_gradient]
end

a = rho0 .* Cp
kT0 = sigma .* 1000.0 ./ a

# Remaining model parameters
Ttop = 8.0
Tbot = Ttop + D * geotherm[2]
cT = 1e-9
mT = 2
g0 = 9.8
aT = 1e-4

yr = 60 * 60 * 24 * 365.25
tend = 1e6 * yr
CFL = 0.9
nop = 100

dTdto = 0.0

# Call appropriate model routine
if conservation == "YES"
    include("temperature_conservation_test.jl")
    temperature_conservation_test()  # assuming this is a function you define
else
    include("helmsRK4.jl")
    helmsRK4()  # assuming this is a function you define
end

# %%
#Define user specified parameters 

no_of_rock_units = 7
W = 3933
Nx = 100
D = 5000

tend = 1e6 #end time in years
k0 = 1e-6 #diffusion coefficient in m^2/s
# Out:
# 1.0e-6

# %%
function read_image(no_of_rock_units:: Int, W::Int, Nx::Int)

    #Load in the cleaned domain image
    
    #state the filename with a shorthand variable name for easier reference 
    pic_path = "M:/Dissertation Code/UistDomainCroppedFilled.png"
    domain_image = load(pic_path) #load image from named pic_path
    
    # Remove alpha channel from RGBA image
    domain_image_rgb = map(RGB, domain_image)  # convert RGBA to RGB


    #record the dimensions of the image 
    p, q = size(domain_image)
    #k = 3 #standard RGB channels 


    domain_img_rgb = channelview(domain_image_rgb)

    reshape_rgb_for_cluster = reshape(domain_img_rgb, (3, p*q)) #this reshapes the image into a 2D array with each pixel as a row and the rgb values as columns



    #cluster using k means to group similar RGB values together so that cluster IDs can be assigned in the model to each rock type
    no_clusters = no_of_rock_units #this is the number of different rock bodies / colours in the image including the sky and the fractures
    clustered_rgb = kmeans(reshape_rgb_for_cluster, no_clusters)
    cluster_ids = clustered_rgb.assignments #this is the cluster ID for each pixel in the image, used as a label later on
    cluster_centres = clustered_rgb.centers #this is the RGB value for each cluster centre; i.e. the mean colour in each cluster


    #sort the cluster ids based on cluster centroid vertical position 
    cluster_id_image = reshape(cluster_ids, (p, q)) #this reshapes the cluster ids back into a 2D array with the same dimensions as the original image

    #compute the spatial centroids

    cluster_xy = zeros(Float64, no_clusters, 2) #this will hold the x and y coordinates of the cluster centroids

    for i = 1:no_clusters
        clust_coords = findall(cluster_id_image .== i) #find the coordinates of the pixels in cluster number i 
        if !isempty(clust_coords) #ensure that the current cluster is not empty
            ys = getindex.(clust_coords, 1)
            xs = getindex.(clust_coords, 2)


            cluster_xy[i, 1] = mean(xs) #compute the mean x coordinate of the pixels in cluster i
            cluster_xy[i, 2] = mean(ys) #compute the mean y coordinate of the pixels in cluster i
        else
            cluster_xy[i,:] = Inf
        end
    end

    sort_cluster_ids = sortperm(cluster_xy[:, 2]) #sort the cluster ids based on the y coordinate of the cluster centroid

    unit_labels = zeros(Int, p, q) #this will hold the unit labels for each pixel in the image
    for i = 1:no_clusters
        unit_labels[cluster_id_image .== sort_cluster_ids[i]] .= i #assign the unit label to each pixel in the image based on the sorted cluster ids
    end

    cluster_id_image = reshape(unit_labels, p, q) #each pixel in this grid stores its cluster id kind of like a map of the original image but each pixel stored an ID instead of a colour


    #Define Model dimensions
    D = W * p / q #calculate model depth, this preserves the aspect ratio of the image 
    Nz = Int(floor(Nx * p/q))

    pix_width = W / p #calculate the pixel width in the model 
    pix_x_centres = pix_width/2 : pix_width: W - pix_width/2 #calculate the x coordinates of the pixel centres
    pix_z_centres = pix_width/2 : pix_width: D - pix_width/2 #calculate the z coordinates of the pixel centres

    image_grid_x = repeat(pix_x_centres', Nz, 1)# create a grid of x coordinates for the image
    image_grid_z = repeat(pix_z_centres, 1, Nx) # create a grid of z coordinates for the image

    #define model grid onto which we can interpolate 
    cell_width = W / Nx #calculate the cell width in the model

    #calculate the midpoints of grid cells 
    cell_x_centres = cell_width/2 : cell_width: W - cell_width/2 #calculate the x coordinates of the cell centres
    cell_z_centres = cell_width/2 : cell_width: D - cell_width/2 #calculate the z coordinates of the cell centres

    model_grid_x = repeat(cell_x_centres', Nz, 1) # create a grid of x coordinates for the model
    model_grid_z = repeat(cell_z_centres, 1, Nx) # create a grid of z coordinates for the model

    ###Interplation###
    #cluster_id_image_f = Float64.(cluster_id_image)
    #itp = interpolate(cluster_id_image_f, BSpline(Linear()), OnGrid())
    #interpolation = extrapolate(itp, Flat())
    

    #img_interp = zeros(Float64, length(cell_z_centres), length(cell_x_centres)) #initialise the matrix for the interpolated image 

    # Interpolation with bounds clamped
    #for i in 1:length(cell_z_centres)
    #    for j in 1:length(cell_x_centres)
   #         z_pos = clamp(cell_z_centres[i] / pix_width, 1.0, size(cluster_id_image, 1))
    #        x_pos = clamp(cell_x_centres[j] / pix_width, 1.0, size(cluster_id_image, 2))
    ##        img_interp[i, j] = interpolation[z_pos, x_pos]
    #    end
    #end

    ### Interpolation ###
    cluster_id_image_f = Float64.(cluster_id_image)
    
        # Define the real coordinates of the image pixel centers
    z_vals = range(0, stop=D, length=size(cluster_id_image, 1))  # depth (rows)
    x_vals = range(0, stop=W, length=size(cluster_id_image, 2))  # width (cols)

    # Create interpolator over real-world coordinates
    itp = interpolate((z_vals, x_vals), cluster_id_image_f, Gridded(Linear()))

    # Now evaluate directly at model grid centres (also in real-world coords)
    img_interp = zeros(Float64, Nz, Nx)

    for i in 1:Nz
        for j in 1:Nx
            z = cell_z_centres[i]  # real-world coordinate
            x = cell_x_centres[j]
            img_interp[i, j] = itp(z, x)  # safe, real-world interpolation
        end
    end

    
    heatmap(pix_x_centres, pix_z_centres, cluster_id_image; aspect_ratio=:equal, title="Original Image")
    heatmap(cell_x_centres, cell_z_centres, img_interp; aspect_ratio=:equal, title="Interpolated Units")

    return UInt8.(clamp.(round.(img_interp), 0, 255)), D, Nz #restrict the values to be between 0 and 255 for storage as an unsigned 8 bit integer 
    #return UInt8.(img_interp), D, Nz
end
# Out:
# read_image (generic function with 1 method)

# %%
function diffusion(T::Array{Float64,2}, k0::Array{Float64, 2}, dx::Float64, ix::Vector{Int}, iz::Vector{Int}, geotherm::Tuple{Float64, Float64})
        #average thermal conductivity from the faces so that they 'lie' in the middle where the temp is
        kx = (k[:, ix[1:end-1]] + k[:, ix[2:end]]) ./ 2 #thermal conductivity in x direction
        kz = (k[iz[1:end-1], :] + k[:, iz[2:end]]) ./ 2 #thermal conductivity in z direction 

        

        qx= - kx .* diff(T[:, ix], dims=2) ./ dx #heat flux in x direction 
        qz = - kz .* diff(T[iz, :], dims=1) ./ dx #heat flux in z direction

        qz[end, :] .= -kz[end, :] .* geotherm[2] #apply boundary condition at the bottom of the model

        dqx = diff(qx, dims=2) ./ dx #change in heat flux in x direction
        dqz = diff(qz, dims=1) ./ dx #change in heat flux in z direction

        dTdt_diffusion = - (dqx + dqz) #change in temperature due to diffusion

        return dTdt_diffusion
end
# Out:
# diffusion (generic function with 1 method)

# %%
function makefigure(x::Vector{Float64}, z::Vector{Float64}, T::Array{Float64,2})
    
    figure()
    imshow(T, extent=(x[1], x[end], z[end], z[1]), aspect="auto", cmap="viridis")
    colorbar(label="Temperature (Celsius)")

    #Add contour lines 
    
    cs1 = contour(x, z, T, levels = [100.0], colors="r", linewidths = 3)
    clabel(cs1, inline = true, fontsize = 14, fmt = "%.0f", colors = "r")

    cs2 = contour(x, z, T, levels = [150.0], colors="r", linewidths = 3)
    clabel(cs2, inline = true, fontsize = 14, fmt = "%.0f", colors = "r")

    xlabel("Horizontal Distance (m)", fontsize = 20)
    ylabel("Depth (m)", fontsize = 20)
    title("Sub Surface Temperature Distribution", fontsize = 24)
    gca().set_aspect("equal") 
    tight_layout() 
    draw()
end
# Out:
# makefigure (generic function with 1 method)

# %%
pic_path = "M:/Dissertation Code/UistDomainCroppedFilled.png"
domain_image = load(pic_path)
println("Image size: ", size(domain_image))
units, D, Nz = read_image(no_of_rock_units, W, Nx)
#read_image(width, no of cells sideways)
# Out:
# Image size: (799, 628)
# (UInt8[0x01 0x01 … 0x01 0x01; 0x01 0x01 … 0x01 0x01; … ; 0x07 0x07 … 0x07 0x07; 0x07 0x07 … 0x07 0x07], 5003.928343949045, 127)

# %%
ix = reshape(vcat(1, collect(1:Nx), Nx), 1, :)  #'create a padded vector with a cushion of 1 and Nx on each end 
iz = reshape(vcat(1, collect(1:Nz), Nz), :, 1) #do the same in the z direction  


Ttop = 11.74 #annual average temp from Met Office 
geotherm = [0, 30/100] #geothermal gradient in C/km typical values from 22-31 deg per km, ask about non linear geotherm 



cell_width = W / Nx #calculate the cell width in the model
cell_x_centres = cell_width/2 : cell_width: W - cell_width/2 #calculate the x coordinates of the cell centres
cell_z_centres = cell_width/2 : cell_width: D - cell_width/2 #calculate the z coordinates of the cell centres


T = Ttop .+ geotherm[2].*cell_z_centres #calculate the temperature at each depth based on the top temperature and the geothermal gradient
Tbottom = Ttop + geotherm[2] * D / 1000 #calculate the bottom temperature based on the top temperature and the geothermal gradient
Tair = Ttop 

rho_gradient = rho0 .* (1 .- aT .* (T - Ttop)) #calculate the density gradient based on the temperature gradient and the thermal expansion coefficient

dt = CFL * ((cell_width/2)^2)/max(kT) #calculate the time step based on the CFL condition and the thermal diffusivity 
println("Time step: ", dt)

t=0 
k=0 
dTdt = 0 

while t <= tend
    # Increment time and step count
    t += dt
    k += 1

    # Store old temperature and rate
    dTdto = dTdt
    To = T

    # Compute rate of change using Runge-Kutta 4th order method
    dTdt1 = diffusion(T, kT, h, ix3, iz3, geotherm)
    dTdt2 = diffusion(T .+ dTdt1 .* (dt/2), kT, h, ix3, iz3, geotherm)
    dTdt3 = diffusion(T .+ dTdt2 .* (dt/2), kT, h, ix3, iz3, geotherm)
    dTdt4 = diffusion(T .+ dTdt3 .* dt,    kT, h, ix3, iz3, geotherm)

    # Calculate heat source contribution 
    Hs = (Hr .* 1e-6) ./ (rho .* Cp)

    # Update temperature using the RK4 method 
    T .= T .+ (dTdt1 .+ 2 .* dTdt2 .+ 2 .* dTdt3 .+ dTdt4) .* (dt/6) .+ Hs

    # Keep air layer at constant temperature
    T[air] .= Ttop

    # Plot every 'nop' time steps
    if k % nop == 0
        makefig(xc, zc, T)
    end
end
# Out:
# UndefVarError: `rho0` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ h:\Dissertation Code\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X14sZmlsZQ==.jl:19

# %%
###Main Body###

#recall that Nx was set at 100 above
#recall that Nz was defined above as well 


cell_x_centres = range(cell_width/2, stop=W-(cell_width/2), length = Nx) #calculate the x coordinates of the cell centres
cell_z_centres = range(cell_width/2, stop=D-(cell_width/2), length = Nz) #calculate the z coordinates of the cell centres
cell_x_faces = range(0, stop=W, length = Nx + 1) #calculate the x coordinates of the cell faces
cell_z_faces = range(0, stop=D, length = Nz + 1) #calculate the z coordinates of the cell faces

println(size(cell_x_centres), "<- Cell X Centres ", size(cell_z_centres), "<- Cell Z Centres ", size(cell_x_faces), " <- Cell X Faces", size(cell_z_faces), " <- Cell Z Faces")


cell_x_faces = 0: cell_width :W
cell_z_faces = 0: cell_width :D

X_cell_centres_matrix = repeat(cell_x_centres', Nz, 1) # create a grid of x coordinates for the model
Z_cell_centres_matrix = repeat(cell_z_centres, 1, Nx) # create a grid of z coordinates for the model

###Initial Conditions###
T = Ttop .+ geotherm .* Z_cell_centres_matrix #calculate the temperature at each cell centre using the geothermal gradient and the top temperature
# Out:
# UndefVarError: `cell_width` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ h:\Dissertation Code\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sZmlsZQ==.jl:7
